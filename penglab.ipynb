# %%
#Penglab (Abuse of Google Colab for fun and profit)

#Choose what you want to install
ssh = True
hashcat = True
john = True
hydra = True

# %%
#Install of hashcat
if hashcat:
    print("Installation of hashcat...")
    # !apt install cmake build-essential -y
    # !apt install checkinstall git -y
    # !git clone https://github.com/hashcat/hashcat.git && cd hashcat && make && make install
# Out:
# Installation of hashcat...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 32 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.17.1-1ubuntu0.4).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   file libmagic-mgc libmagic1
# Suggested packages:
#   gettext
# The following NEW packages will be installed:
#   checkinstall file libmagic-mgc libmagic1
# 0 upgraded, 4 newly installed, 0 to remove and 32 not upgraded.
# Need to get 372 kB of archives.
# After this operation, 5,732 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.3 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.3 [68.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.3 [22.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 checkinstall amd64 1.6.2-4ubuntu2 [97.1 kB]
# Fetched 372 kB in 1s (349 kB/s)
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 145605 files and directories currently installed.)
# Preparing to unpack .../libmagic-mgc_1%3a5.32-2ubuntu0.3_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.3) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../libmagic1_1%3a5.32-2ubuntu0.3_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.3) ...
# Selecting previously unselected package file.
# Preparing to unpack .../file_1%3a5.32-2ubuntu0.3_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.3) ...
# Selecting previously unselected package checkinstall.
# Preparing to unpack .../checkinstall_1.6.2-4ubuntu2_amd64.deb ...
# Unpacking checkinstall (1.6.2-4ubuntu2) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.3) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.3) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up file (1:5.32-2ubuntu0.3) ...
# Setting up checkinstall (1.6.2-4ubuntu2) ...
# Cloning into 'hashcat'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 60467 (delta 5), reused 9 (delta 3), pack-reused 60447
# Receiving objects: 100% (60467/60467), 46.02 MiB | 23.62 MiB/s, done.
# Resolving deltas: 100% (51561/51561), done.
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/affinity.c -o obj/affinity.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/autotune.c -o obj/autotune.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/backend.c -o obj/backend.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/benchmark.c -o obj/benchmark.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/bitmap.c -o obj/bitmap.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/bitops.c -o obj/bitops.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/combinator.c -o obj/combinator.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/common.c -o obj/common.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/convert.c -o obj/convert.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/cpt.c -o obj/cpt.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/cpu_crc32.c -o obj/cpu_crc32.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/debugfile.c -o obj/debugfile.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/dictstat.c -o obj/dictstat.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/dispatch.c -o obj/dispatch.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/dynloader.c -o obj/dynloader.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/event.c -o obj/event.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/ext_ADL.c -o obj/ext_ADL.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/ext_cuda.c -o obj/ext_cuda.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/ext_nvapi.c -o obj/ext_nvapi.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/ext_nvml.c -o obj/ext_nvml.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/ext_nvrtc.c -o obj/ext_nvrtc.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/ext_OpenCL.c -o obj/ext_OpenCL.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/ext_sysfs.c -o obj/ext_sysfs.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/ext_lzma.c -o obj/ext_lzma.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON -Wno-unused-parameter -Wno-unused-function -Wno-nonnull-compare -Ideps/secp256k1//src/ -Ideps/secp256k1/ src/ext_secp256k1.c -o obj/ext_secp256k1.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/filehandling.c -o obj/filehandling.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/folder.c -o obj/folder.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/hashcat.c -o obj/hashcat.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/hashes.c -o obj/hashes.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/hlfmt.c -o obj/hlfmt.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/hwmon.c -o obj/hwmon.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/induct.c -o obj/induct.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/interface.c -o obj/interface.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/keyboard_layout.c -o obj/keyboard_layout.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/locking.c -o obj/locking.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/logfile.c -o obj/logfile.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/loopback.c -o obj/loopback.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/memory.c -o obj/memory.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/monitor.c -o obj/monitor.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/mpsp.c -o obj/mpsp.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/outfile_check.c -o obj/outfile_check.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/outfile.c -o obj/outfile.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/pidfile.c -o obj/pidfile.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/potfile.c -o obj/potfile.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/restore.c -o obj/restore.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/rp.c -o obj/rp.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/rp_cpu.c -o obj/rp_cpu.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/selftest.c -o obj/selftest.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/slow_candidates.c -o obj/slow_candidates.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/shared.c -o obj/shared.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/status.c -o obj/status.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/stdout.c -o obj/stdout.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/straight.c -o obj/straight.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/terminal.c -o obj/terminal.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/thread.c -o obj/thread.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/timer.c -o obj/timer.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/tuningdb.c -o obj/tuningdb.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/usage.c -o obj/usage.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/user_options.c -o obj/user_options.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/wordlist.c -o obj/wordlist.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_general.c -o obj/emu_general.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_common.c -o obj/emu_inc_common.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_platform.c -o obj/emu_inc_platform.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_scalar.c -o obj/emu_inc_scalar.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_simd.c -o obj/emu_inc_simd.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_rp.c -o obj/emu_inc_rp.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_rp_optimized.c -o obj/emu_inc_rp_optimized.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_truecrypt_crc32.c -o obj/emu_inc_truecrypt_crc32.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_truecrypt_keyfile.c -o obj/emu_inc_truecrypt_keyfile.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_truecrypt_xts.c -o obj/emu_inc_truecrypt_xts.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_veracrypt_xts.c -o obj/emu_inc_veracrypt_xts.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_hash_md4.c -o obj/emu_inc_hash_md4.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_hash_md5.c -o obj/emu_inc_hash_md5.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_hash_ripemd160.c -o obj/emu_inc_hash_ripemd160.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_hash_sha1.c -o obj/emu_inc_hash_sha1.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_hash_sha256.c -o obj/emu_inc_hash_sha256.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_hash_sha384.c -o obj/emu_inc_hash_sha384.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_hash_sha512.c -o obj/emu_inc_hash_sha512.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_hash_streebog256.c -o obj/emu_inc_hash_streebog256.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_hash_streebog512.c -o obj/emu_inc_hash_streebog512.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_cipher_aes.c -o obj/emu_inc_cipher_aes.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_cipher_camellia.c -o obj/emu_inc_cipher_camellia.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_cipher_des.c -o obj/emu_inc_cipher_des.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_cipher_kuznyechik.c -o obj/emu_inc_cipher_kuznyechik.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_cipher_serpent.c -o obj/emu_inc_cipher_serpent.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/emu_inc_cipher_twofish.c -o obj/emu_inc_cipher_twofish.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/brain.c -o obj/brain.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON deps/LZMA-SDK/C/Alloc.c -o obj/Alloc.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON deps/LZMA-SDK/C/Lzma2Dec.c -o obj/Lzma2Dec.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON deps/LZMA-SDK/C/LzmaDec.c -o obj/LzmaDec.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON -Wno-implicit-fallthrough -Wno-implicit-function-declaration -Wno-unused-parameter -DIOAPI_NO_64 deps/zlib//adler32.c -o obj/adler32.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON -Wno-implicit-fallthrough -Wno-implicit-function-declaration -Wno-unused-parameter -DIOAPI_NO_64 deps/zlib//crc32.c -o obj/crc32.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON -Wno-implicit-fallthrough -Wno-implicit-function-declaration -Wno-unused-parameter -DIOAPI_NO_64 deps/zlib//deflate.c -o obj/deflate.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON -Wno-implicit-fallthrough -Wno-implicit-function-declaration -Wno-unused-parameter -DIOAPI_NO_64 deps/zlib//inflate.c -o obj/inflate.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON -Wno-implicit-fallthrough -Wno-implicit-function-declaration -Wno-unused-parameter -DIOAPI_NO_64 deps/zlib//inffast.c -o obj/inffast.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON -Wno-implicit-fallthrough -Wno-implicit-function-declaration -Wno-unused-parameter -DIOAPI_NO_64 deps/zlib//inftrees.c -o obj/inftrees.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON -Wno-implicit-fallthrough -Wno-implicit-function-declaration -Wno-unused-parameter -DIOAPI_NO_64 deps/zlib//trees.c -o obj/trees.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON -Wno-implicit-fallthrough -Wno-implicit-function-declaration -Wno-unused-parameter -DIOAPI_NO_64 deps/zlib//gzread.c -o obj/gzread.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON -Wno-implicit-fallthrough -Wno-implicit-function-declaration -Wno-unused-parameter -DIOAPI_NO_64 deps/zlib//gzwrite.c -o obj/gzwrite.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON -Wno-implicit-fallthrough -Wno-implicit-function-declaration -Wno-unused-parameter -DIOAPI_NO_64 deps/zlib//gzclose.c -o obj/gzclose.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON -Wno-implicit-fallthrough -Wno-implicit-function-declaration -Wno-unused-parameter -DIOAPI_NO_64 deps/zlib//zutil.c -o obj/zutil.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON -Wno-implicit-fallthrough -Wno-implicit-function-declaration -Wno-unused-parameter -DIOAPI_NO_64 deps/zlib//gzlib.c -o obj/gzlib.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON -Wno-implicit-fallthrough -Wno-implicit-function-declaration -Wno-unused-parameter -DIOAPI_NO_64 deps/zlib//contrib/minizip/unzip.c -o obj/contrib/minizip/unzip.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON -Wno-implicit-fallthrough -Wno-implicit-function-declaration -Wno-unused-parameter -DIOAPI_NO_64 deps/zlib//contrib/minizip/ioapi.c -o obj/contrib/minizip/ioapi.NATIVE.o -fpic
# gcc -c -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON deps/xxHash/xxhash.c -o obj/xxhash.NATIVE.o -fpic
# ar rcs obj/combined.NATIVE.a obj/affinity.NATIVE.o obj/autotune.NATIVE.o obj/backend.NATIVE.o obj/benchmark.NATIVE.o obj/bitmap.NATIVE.o obj/bitops.NATIVE.o obj/combinator.NATIVE.o obj/common.NATIVE.o obj/convert.NATIVE.o obj/cpt.NATIVE.o obj/cpu_crc32.NATIVE.o obj/debugfile.NATIVE.o obj/dictstat.NATIVE.o obj/dispatch.NATIVE.o obj/dynloader.NATIVE.o obj/event.NATIVE.o obj/ext_ADL.NATIVE.o obj/ext_cuda.NATIVE.o obj/ext_nvapi.NATIVE.o obj/ext_nvml.NATIVE.o obj/ext_nvrtc.NATIVE.o obj/ext_OpenCL.NATIVE.o obj/ext_sysfs.NATIVE.o obj/ext_lzma.NATIVE.o obj/ext_secp256k1.NATIVE.o obj/filehandling.NATIVE.o obj/folder.NATIVE.o obj/hashcat.NATIVE.o obj/hashes.NATIVE.o obj/hlfmt.NATIVE.o obj/hwmon.NATIVE.o obj/induct.NATIVE.o obj/interface.NATIVE.o obj/keyboard_layout.NATIVE.o obj/locking.NATIVE.o obj/logfile.NATIVE.o obj/loopback.NATIVE.o obj/memory.NATIVE.o obj/monitor.NATIVE.o obj/mpsp.NATIVE.o obj/outfile_check.NATIVE.o obj/outfile.NATIVE.o obj/pidfile.NATIVE.o obj/potfile.NATIVE.o obj/restore.NATIVE.o obj/rp.NATIVE.o obj/rp_cpu.NATIVE.o obj/selftest.NATIVE.o obj/slow_candidates.NATIVE.o obj/shared.NATIVE.o obj/status.NATIVE.o obj/stdout.NATIVE.o obj/straight.NATIVE.o obj/terminal.NATIVE.o obj/thread.NATIVE.o obj/timer.NATIVE.o obj/tuningdb.NATIVE.o obj/usage.NATIVE.o obj/user_options.NATIVE.o obj/wordlist.NATIVE.o obj/emu_general.NATIVE.o obj/emu_inc_common.NATIVE.o obj/emu_inc_platform.NATIVE.o obj/emu_inc_scalar.NATIVE.o obj/emu_inc_simd.NATIVE.o obj/emu_inc_rp.NATIVE.o obj/emu_inc_rp_optimized.NATIVE.o obj/emu_inc_truecrypt_crc32.NATIVE.o obj/emu_inc_truecrypt_keyfile.NATIVE.o obj/emu_inc_truecrypt_xts.NATIVE.o obj/emu_inc_veracrypt_xts.NATIVE.o obj/emu_inc_hash_md4.NATIVE.o obj/emu_inc_hash_md5.NATIVE.o obj/emu_inc_hash_ripemd160.NATIVE.o obj/emu_inc_hash_sha1.NATIVE.o obj/emu_inc_hash_sha256.NATIVE.o obj/emu_inc_hash_sha384.NATIVE.o obj/emu_inc_hash_sha512.NATIVE.o obj/emu_inc_hash_streebog256.NATIVE.o obj/emu_inc_hash_streebog512.NATIVE.o obj/emu_inc_cipher_aes.NATIVE.o obj/emu_inc_cipher_camellia.NATIVE.o obj/emu_inc_cipher_des.NATIVE.o obj/emu_inc_cipher_kuznyechik.NATIVE.o obj/emu_inc_cipher_serpent.NATIVE.o obj/emu_inc_cipher_twofish.NATIVE.o obj/brain.NATIVE.o obj/Alloc.NATIVE.o obj/Lzma2Dec.NATIVE.o obj/LzmaDec.NATIVE.o obj/adler32.NATIVE.o obj/crc32.NATIVE.o obj/deflate.NATIVE.o obj/inflate.NATIVE.o obj/inffast.NATIVE.o obj/inftrees.NATIVE.o obj/trees.NATIVE.o obj/gzread.NATIVE.o obj/gzwrite.NATIVE.o obj/gzclose.NATIVE.o obj/zutil.NATIVE.o obj/gzlib.NATIVE.o obj/contrib/minizip/unzip.NATIVE.o obj/contrib/minizip/ioapi.NATIVE.o obj/xxhash.NATIVE.o
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/main.c obj/combined.NATIVE.a -o hashcat                     -s -lpthread -ldl -lrt -lm -DCOMPTIME=1575323655 -DVERSION_TAG=\"v5.1.0-1487-g79bec2b5\" -DINSTALL_FOLDER=\"/usr/local/bin\" -DSHARED_FOLDER=\"/usr/local/share/hashcat\" -DDOCUMENT_FOLDER=\"/usr/local/share/doc/hashcat\"
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_08200.c obj/combined.NATIVE.a -o modules/module_08200.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_11200.c obj/combined.NATIVE.a -o modules/module_11200.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_13741.c obj/combined.NATIVE.a -o modules/module_13741.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_07200.c obj/combined.NATIVE.a -o modules/module_07200.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_00150.c obj/combined.NATIVE.a -o modules/module_00150.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_11760.c obj/combined.NATIVE.a -o modules/module_11760.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_05200.c obj/combined.NATIVE.a -o modules/module_05200.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_16000.c obj/combined.NATIVE.a -o modules/module_16000.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_06232.c obj/combined.NATIVE.a -o modules/module_06232.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_19100.c obj/combined.NATIVE.a -o modules/module_19100.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_06223.c obj/combined.NATIVE.a -o modules/module_06223.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_18500.c obj/combined.NATIVE.a -o modules/module_18500.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_11860.c obj/combined.NATIVE.a -o modules/module_11860.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_00020.c obj/combined.NATIVE.a -o modules/module_00020.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_11900.c obj/combined.NATIVE.a -o modules/module_11900.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_06500.c obj/combined.NATIVE.a -o modules/module_06500.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_13712.c obj/combined.NATIVE.a -o modules/module_13712.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_01100.c obj/combined.NATIVE.a -o modules/module_01100.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_00011.c obj/combined.NATIVE.a -o modules/module_00011.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_00101.c obj/combined.NATIVE.a -o modules/module_00101.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_10000.c obj/combined.NATIVE.a -o modules/module_10000.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_09710.c obj/combined.NATIVE.a -o modules/module_09710.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_00300.c obj/combined.NATIVE.a -o modules/module_00300.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_04522.c obj/combined.NATIVE.a -o modules/module_04522.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_01400.c obj/combined.NATIVE.a -o modules/module_01400.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_06700.c obj/combined.NATIVE.a -o modules/module_06700.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_01441.c obj/combined.NATIVE.a -o modules/module_01441.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_12300.c obj/combined.NATIVE.a -o modules/module_12300.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_13200.c obj/combined.NATIVE.a -o modules/module_13200.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_15000.c obj/combined.NATIVE.a -o modules/module_15000.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_14400.c obj/combined.NATIVE.a -o modules/module_14400.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_20800.c obj/combined.NATIVE.a -o modules/module_20800.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_13600.c obj/combined.NATIVE.a -o modules/module_13600.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_13722.c obj/combined.NATIVE.a -o modules/module_13722.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_01460.c obj/combined.NATIVE.a -o modules/module_01460.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# ...
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_19700.c obj/combined.NATIVE.a -o modules/module_19700.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_06241.c obj/combined.NATIVE.a -o modules/module_06241.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_09200.c obj/combined.NATIVE.a -o modules/module_09200.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_00111.c obj/combined.NATIVE.a -o modules/module_00111.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_18900.c obj/combined.NATIVE.a -o modules/module_18900.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_11750.c obj/combined.NATIVE.a -o modules/module_11750.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_20200.c obj/combined.NATIVE.a -o modules/module_20200.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_12000.c obj/combined.NATIVE.a -o modules/module_12000.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_13900.c obj/combined.NATIVE.a -o modules/module_13900.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_09810.c obj/combined.NATIVE.a -o modules/module_09810.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_12200.c obj/combined.NATIVE.a -o modules/module_12200.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_00130.c obj/combined.NATIVE.a -o modules/module_00130.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_17800.c obj/combined.NATIVE.a -o modules/module_17800.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_02400.c obj/combined.NATIVE.a -o modules/module_02400.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_21700.c obj/combined.NATIVE.a -o modules/module_21700.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_04110.c obj/combined.NATIVE.a -o modules/module_04110.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_20011.c obj/combined.NATIVE.a -o modules/module_20011.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_11600.c obj/combined.NATIVE.a -o modules/module_11600.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_01411.c obj/combined.NATIVE.a -o modules/module_01411.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_14100.c obj/combined.NATIVE.a -o modules/module_14100.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_13711.c obj/combined.NATIVE.a -o modules/module_13711.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_11400.c obj/combined.NATIVE.a -o modules/module_11400.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_15400.c obj/combined.NATIVE.a -o modules/module_15400.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_18100.c obj/combined.NATIVE.a -o modules/module_18100.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_10800.c obj/combined.NATIVE.a -o modules/module_10800.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_09300.c obj/combined.NATIVE.a -o modules/module_09300.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_10410.c obj/combined.NATIVE.a -o modules/module_10410.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_13752.c obj/combined.NATIVE.a -o modules/module_13752.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_21600.c obj/combined.NATIVE.a -o modules/module_21600.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_01450.c obj/combined.NATIVE.a -o modules/module_01450.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# gcc    -W -Wall -Wextra -Wno-cast-function-type -O2 -pipe -std=gnu99 -Iinclude/ -IOpenCL/ -Ideps/LZMA-SDK/C -Ideps/zlib/ -Ideps/secp256k1//include/ -Ideps/OpenCL-Headers -DWITH_BRAIN -Ideps/xxHash -DWITH_HWMON src/modules/module_17500.c obj/combined.NATIVE.a -o modules/module_17500.so  -s -lpthread -ldl -lrt -lm -shared -fPIC -D MODULE_INTERFACE_VERSION_CURRENT=520
# install -m 755 -d                                                    /usr/local/share
# install -m 755 -d                                                    /usr/local/bin
# install -m 755 hashcat                                   /usr/local/bin/
# install -m 755 -d                                                    /usr/local/share/doc/hashcat
# install -m 755 -d                                                    /usr/local/share/hashcat
# install -m 644 hashcat.hctune                                        /usr/local/share/hashcat/
# install -m 755 -d                                                    /usr/local/share/doc/hashcat/charsets
# install -m 644 hashcat.hcstat2                                       /usr/local/share/hashcat/
# install -m 755 -d                                                    /usr/local/share/doc/hashcat/docs
# install -m 755 -d                                                    /usr/local/share/doc/hashcat/layouts
# install -m 755 -d                                                    /usr/local/share/hashcat/OpenCL
# install -m 755 -d                                                    /usr/local/share/hashcat/modules
# find OpenCL/   -mindepth 1 -type d -execdir install -m 755 -d     /usr/local/share/hashcat/OpenCL/{} \;
# install -m 755 -d                                                    /usr/local/share/doc/hashcat/masks
# find modules/  -mindepth 1 -type d -execdir install -m 755 -d     /usr/local/share/hashcat/modules/{} \;
# install -m 755 -d                                                    /usr/local/share/doc/hashcat/rules
# install -m 755 -d                                                    /usr/local/share/doc/hashcat/extra
# install -m 755 -d                                                    /usr/local/share/doc/hashcat/extra/tab_completion
# find modules/  -mindepth 1 -type f -execdir install -m 644 {}     /usr/local/share/hashcat/modules/{} \;
# find OpenCL/   -mindepth 1 -type f -execdir install -m 644 {}     /usr/local/share/hashcat/OpenCL/{} \;
# install -m 644 example.dict                                          /usr/local/share/doc/hashcat/
# install -m 644 example0.hash                                         /usr/local/share/doc/hashcat/
# install -m 644 example400.hash                                       /usr/local/share/doc/hashcat/
# install -m 644 example500.hash                                       /usr/local/share/doc/hashcat/
# install -m 755 example0.sh                                           /usr/local/share/doc/hashcat/
# install -m 755 example400.sh                                         /usr/local/share/doc/hashcat/
# install -m 755 example500.sh                                         /usr/local/share/doc/hashcat/
# install -m 644 extra/tab_completion/hashcat.sh                       /usr/local/share/doc/hashcat/extra/tab_completion/
# install -m 644 extra/tab_completion/howto.txt                        /usr/local/share/doc/hashcat/extra/tab_completion/
# install -m 755 extra/tab_completion/install                          /usr/local/share/doc/hashcat/extra/tab_completion/
# find charsets/ -type d -exec install -m 755 -d                    /usr/local/share/doc/hashcat/{} \;
# find charsets/ -type f -exec install -m 644 {}                    /usr/local/share/doc/hashcat/{} \;
# find docs/     -type d -exec install -m 755 -d                    /usr/local/share/doc/hashcat/{} \;
# find docs/     -type f -exec install -m 644 {}                    /usr/local/share/doc/hashcat/{} \;
# find layouts/  -type d -exec install -m 755 -d                    /usr/local/share/doc/hashcat/{} \;
# find layouts/  -type f -exec install -m 644 {}                    /usr/local/share/doc/hashcat/{} \;
# find masks/    -type d -exec install -m 755 -d                    /usr/local/share/doc/hashcat/{} \;
# find masks/    -type f -exec install -m 644 {}                    /usr/local/share/doc/hashcat/{} \;
# find rules/    -type d -exec install -m 755 -d                    /usr/local/share/doc/hashcat/{} \;
# find rules/    -type f -exec install -m 644 {}                    /usr/local/share/doc/hashcat/{} \;
# sed -i 's/\.\/hashcat/hashcat/'                         /usr/local/share/doc/hashcat/example0.sh
# sed -i 's/\.\/hashcat/hashcat/'                         /usr/local/share/doc/hashcat/example400.sh
# sed -i 's/\.\/hashcat/hashcat/'                         /usr/local/share/doc/hashcat/example500.sh

# %%
#Install of john
if ssh:
    print("Installation of john...")
    # !apt-get install john -y
# Out:
# Installation of john...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   john-data
# Suggested packages:
#   wordlist
# The following NEW packages will be installed:
#   john john-data
# 0 upgraded, 2 newly installed, 0 to remove and 32 not upgraded.
# Need to get 4,466 kB of archives.
# After this operation, 7,875 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 john-data all 1.8.0-2build1 [4,276 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 john amd64 1.8.0-2build1 [189 kB]
# Fetched 4,466 kB in 2s (2,774 kB/s)
# Selecting previously unselected package john-data.
# (Reading database ... 145669 files and directories currently installed.)
# Preparing to unpack .../john-data_1.8.0-2build1_all.deb ...
# Unpacking john-data (1.8.0-2build1) ...
# Selecting previously unselected package john.
# Preparing to unpack .../john_1.8.0-2build1_amd64.deb ...
# Unpacking john (1.8.0-2build1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up john-data (1.8.0-2build1) ...
# Setting up john (1.8.0-2build1) ...

# %%
#Install of hydra
if hydra:
    print("Installation of hydra...")
    # !apt install cmake build-essential -y
    # !apt install checkinstall git -y
    # !git clone https://github.com/vanhauser-thc/thc-hydra.git && cd thc-hydra && ./configure && make && make install
# Out:
# Installation of hydra...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 32 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# checkinstall is already the newest version (1.6.2-4ubuntu2).
# git is already the newest version (1:2.17.1-1ubuntu0.4).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 32 not upgraded.
# Cloning into 'thc-hydra'...
# remote: Enumerating objects: 2542, done.
# remote: Total 2542 (delta 0), reused 0 (delta 0), pack-reused 2542
# Receiving objects: 100% (2542/2542), 2.61 MiB | 6.73 MiB/s, done.
# Resolving deltas: 100% (1743/1743), done.
#
# Starting hydra auto configuration ...
# Detected 64 Bit Linux OS
#
# Checking for zlib (libz.so, zlib.h) ...
#                                         ... found
# Checking for openssl (libssl, libcrypto, ssl.h, sha.h) ...
#                                                        ... found
# Checking for gcrypt (libgcrypt.so, gpg-error.h) ...
#                                         ... gcrypt not found, radmin2 module disabled
# Checking for idn (libidn.so) ...
#                              ... NOT found, unicode logins and passwords will not be supported
# Checking for curses (libcurses.so / term.h) ...
#                                             ... found, color output enabled
# Checking for pcre (libpcre.so, pcre.h) ...
#                                        ... found
# Checking for Postgres (libpq.so, libpq-fe.h) ...
#                                              ... NOT found, module postgres disabled
# Checking for SVN (libsvn_client-1 libapr-1.so libaprutil-1.so) ...
#                                                                ... NOT found, module svn disabled
# Checking for firebird (libfbclient.so) ...
#                                        ... NOT found, module firebird disabled
# Checking for MYSQL client (libmysqlclient.so, math.h) ...
#                                                       ... NOT found, module Mysql will not support version > 4.x
# Checking for AFP (libafpclient.so) ...
#                                    ... NOT found, module Apple Filing Protocol disabled - Apple sucks anyway
# Checking for NCP (libncp.so / nwcalls.h) ...
#                                          ... NOT found, module NCP disabled
# Checking for SAP/R3 (librfc/saprfc.h) ...
#                                       ... NOT found, module sapr3 disabled
# Get it from http://www.sap.com/solutions/netweaver/linux/eval/index.asp
# Checking for libssh (libssh/libssh.h) ...
#                                       ... NOT found, module ssh disabled
# Get it from http://www.libssh.org
# Checking for Oracle (libocci.so libclntsh.so / oci.h and libaio.so) ...
#                                                                     ... NOT found, module Oracle disabled
# Get basic and sdk package from http://www.oracle.com/technetwork/database/features/instant-client/index.html
# Checking for Memcached (libmemcached.so, memcached.h) ...
#                                              ... NOT found, module memcached disabled
# Checking for Freerdp2 (libfreerdp2.so, freerdp/*.h, libwinpr2.so, winpr/*.h) ...
#                                              ... NOT found, module rdp disabled
# Checking for Mongodb (libmongoc-1.0.so, mongoc.h, libbson-1.0.so, bson.h) ...
#                                              ... NOT found, module mongodb disabled
# Checking for GUI req's (pkg-config, gtk+-2.0) ...
#                                               ... NOT found, optional anyway
# Checking for Android specialities ...
#                                   ... strrchr() found
#                                   ... RSA_generate_key() found
# Checking for secure compile option support in gcc ...
#                                                   Compiling... yes
#                                                   Linking... yes
#
# Hydra will be installed into .../bin of: /usr/local
#   (change this by running ./configure --prefix=path)
#
# Writing Makefile.in ...
# now type "make"
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro    -o pw-inspector  pw-inspector.c
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-vnc.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-pcnfs.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-rexec.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-nntp.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-socks5.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-telnet.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-cisco.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-http.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-ftp.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-imap.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-pop3.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-smb.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-icq.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-cisco-enable.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-ldap.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-memcached.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-mongodb.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-mysql.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-mssql.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-xmpp.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-http-proxy-urlenum.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-snmp.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-cvs.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-smtp.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-smtp-enum.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-sapr3.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-ssh.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-sshkey.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-teamspeak.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-postgres.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-rsh.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-rlogin.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-oracle-listener.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-svn.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-pcanywhere.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-sip.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-oracle-sid.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-oracle.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-vmauthd.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-asterisk.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-firebird.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-afp.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-ncp.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-http-proxy.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-http-form.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-irc.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-redis.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-rdp.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-adam6500.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-rtsp.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-rpcap.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-radmin2.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c crc32.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c d3des.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c bfg.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c ntlm.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c sasl.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hmacmd5.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-mod.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro   -c hydra-time.c -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H  -I/usr/include -I/usr/include
# cc -I. -O3 -march=native -flto -pie -fPIE -fstack-protector-all --param ssp-buffer-size=4 -D_FORTIFY_SOURCE=2 -Wl,-z,now -Wl,-z,relro -lm    -o hydra  hydra.c hydra-vnc.o hydra-pcnfs.o hydra-rexec.o hydra-nntp.o hydra-socks5.o hydra-telnet.o hydra-cisco.o hydra-http.o hydra-ftp.o hydra-imap.o hydra-pop3.o hydra-smb.o hydra-icq.o hydra-cisco-enable.o hydra-ldap.o hydra-memcached.o hydra-mongodb.o hydra-mysql.o hydra-mssql.o hydra-xmpp.o hydra-http-proxy-urlenum.o hydra-snmp.o hydra-cvs.o hydra-smtp.o hydra-smtp-enum.o hydra-sapr3.o hydra-ssh.o hydra-sshkey.o hydra-teamspeak.o hydra-postgres.o hydra-rsh.o hydra-rlogin.o hydra-oracle-listener.o hydra-svn.o hydra-pcanywhere.o hydra-sip.o hydra-oracle-sid.o hydra-oracle.o hydra-vmauthd.o hydra-asterisk.o hydra-firebird.o hydra-afp.o hydra-ncp.o hydra-http-proxy.o hydra-http-form.o hydra-irc.o hydra-redis.o hydra-rdp.o hydra-s7-300.c hydra-adam6500.o hydra-rtsp.o hydra-rpcap.o hydra-radmin2.o crc32.o d3des.o bfg.o ntlm.o sasl.o hmacmd5.o hydra-mod.o hydra-time.o -lm -lz -lcurses -lssl -lpcre -lcrypto -L/usr/lib -L/usr/local/lib -L/lib -L/usr/lib/x86_64-linux-gnu -L/lib/x86_64-linux-gnu -L/usr/lib/x86_64-linux-gnu -I/usr/include -I/usr/include -DLIBOPENSSL -DLIBNCURSES -DHAVE_PCRE -DHAVE_ZLIB -DHAVE_MATH_H
#
# If men could get pregnant, abortion would be a sacrament
#
#
# Now type make install
#
# Now type make install
# strip hydra pw-inspector
# echo OK > /dev/null && test -x xhydra && strip xhydra || echo OK > /dev/null
# mkdir -p /usr/local/bin
# cp -f hydra-wizard.sh hydra pw-inspector /usr/local/bin && cd /usr/local/bin && chmod 755 hydra-wizard.sh hydra pw-inspector
# echo OK > /dev/null && test -x xhydra && cp xhydra /usr/local/bin && cd /usr/local/bin && chmod 755 xhydra || echo OK > /dev/null
# sed -e "s|^INSTALLDIR=.*|INSTALLDIR="/usr/local"|" dpl4hydra.sh | sed -e "s|^LOCATION=.*|LOCATION="/etc"|" > /usr/local/bin/dpl4hydra.sh
# chmod 755 /usr/local/bin/dpl4hydra.sh
# mkdir -p /usr/local/etc
# cp -f *.csv /usr/local/etc
# mkdir -p /usr/local/man/man1/
# cp -f hydra.1 xhydra.1 pw-inspector.1 /usr/local/man/man1/

# %%
#Setting up SSH
if ssh:
    print("Setting up SSH...")
    # !pip install git+https://github.com/demotomohiro/remocolab.git
    import remocolab
    remocolab.setupSSHD()
# Out:
# Setting up SSH...
# Collecting git+https://github.com/demotomohiro/remocolab.git
#   Cloning https://github.com/demotomohiro/remocolab.git to /tmp/pip-req-build-dt0r2yyo
#   Running command git clone -q https://github.com/demotomohiro/remocolab.git /tmp/pip-req-build-dt0r2yyo
# Building wheels for collected packages: remocolab.py
#   Building wheel for remocolab.py (setup.py) ... done
#   Created wheel for remocolab.py: filename=remocolab.py-0.1-cp36-none-any.whl size=5344 sha256=eb31e3ec632da3a5ab7ad2fbca119d6096218fda4197a610f3cf4b62a6d1c6f2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_1634jvz/wheels/9e/c3/02/22e12a4614e679c5555718bd4d0356e4b7cc1d69a1f3ddb564
# Successfully built remocolab.py
# Installing collected packages: remocolab.py
# Successfully installed remocolab.py-0.1
# ---
# Copy&paste your tunnel authtoken from https://dashboard.ngrok.com/auth
# (You need to sign up for ngrok and login,)
# ··········
# Select your ngrok region:
# us - United States (Ohio)
# eu - Europe (Frankfurt)
# ap - Asia/Pacific (Singapore)
# au - Australia (Sydney)
# sa - South America (Sao Paulo)
# jp - Japan (Tokyo)
# in - India (Mumbai)
# eu
# Install openssh-server
# ECDSA key fingerprint of host:
# 256 SHA256:JKiDX7Sp9kwFFdRGfIbAUVmEon5psJpKTf6HNxJqF4U root@48788748c5a6 (ECDSA)
# +---[ECDSA 256]---+
# |     o*Oo*o      |
# |     oo B o      |
# |    +.oo.o       |
# | . ooE +         |
# |. oo+oo.S        |
# | .++o++          |
# | .+=oo+          |
# |..o*.+ +         |
# |... +.+ .        |
# +----[SHA256]-----+
#
# ✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️
# root password: v72OlyjeMhaUkJtsrc3vU3fdvtvB2jvb_edFvoSfYlo
# colab password: epwAvyfyd3wZAfFR5mrKNr4dSC94zFExGQdRuh1qT0k
# ✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️
# ---
# Command to connect to the ssh server:
# ✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️
# ssh -o UserKnownHostsFile=/dev/null -o VisualHostKey=yes -p 10172 colab@0.tcp.eu.ngrok.io
# ✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️
# ---
# If you use VNC:
# ✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️
# ssh -o UserKnownHostsFile=/dev/null -o VisualHostKey=yes -L 5901:localhost:5901 -p 10172 colab@0.tcp.eu.ngrok.io
# ✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️
